# %% [markdown]
# # Land price prediction by using Linear Regression with Single Variable
# By- Rhushikesh Ugemuge

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv('house dataset.csv')

# %%
print(dataset.shape)
print(dataset.head(5))
# Out:
# (1460, 2)
#     area   price
# 0   8450  208500
# 1   9600  181500
# 2  11250  223500
# 3   9550  140000
# 4  14260  250000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    1460 non-null   int64
#  1   price   1460 non-null   int64
# dtypes: int64(2)
# memory usage: 22.9 KB

# %%
dataset.describe()
# Out:
#                 area          price
# count    1460.000000    1460.000000
# mean    10516.828082  180921.195890
# std      9981.264932   79442.502883
# min      1300.000000   34900.000000
# 25%      7553.500000  129975.000000
# 50%      9478.500000  163000.000000
# 75%     11601.500000  214000.000000
# max    215245.000000  755000.000000

# %%
plt.xlabel("Area")
plt.ylabel("Price")
plt.scatter(dataset.area,dataset.price,color="red",marker="+")

# %%
X = dataset.drop('price',axis='columns')
X
# Out:
#        area
# 0      8450
# 1      9600
# 2     11250
# 3      9550
# 4     14260
# ...     ...
# 1455   7917
# 1456  13175
# 1457   9042
# 1458   9717
# 1459   9937
#
# [1460 rows x 1 columns]

# %%
Y = dataset.price
Y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: price, Length: 1460, dtype: int64

# %%
model = LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
x=2000
LandAreainSqFt=[[x]]
PredictedmodelResult = model.predict(LandAreainSqFt)
print(PredictedmodelResult)
# Out:
# [163036.09580029]

# %%
m=model.coef_
print(m)
# Out:
# [2.09997195]

# %%
b=model.intercept_
print(b)
# Out:
# 158836.1518968766

# %%
y=m*x+b
print("Price of {0} Square feet land is : {1} ".format(x,y[0]))
# Out:
# Price of 2000 Square feet land is : 163036.09580029195
